# %%
import pandas as pd

df = pd.read_excel("MATCH_final-anotasi-pos-taggingg.xlsx")

label_mapping = {
    'PAD':'PAD',
    'ADV': 'ADV',
    'ASP': 'ADV', 
    'B--':'B--',
    'CC-': 'CC-', 
    'CCA': 'CC-',   
    'CCS': 'CC-', 
    'CD': 'CD',
    'X--': 'F--', 
    'F--': 'F--', 
    'DET': 'DET', 
    'NSB': 'NSB', 
    'NSD': 'NSD',
    'NSM': 'NSB',  
    'NSV': 'NSB',
    'NSP': 'NSB',
    'NSP': 'NSD', 
    'NUM':'NUM',
    'ORD':'NUM', 
    'Z--':'Z--',
    'O--':'O--',
    'S--': 'S--',
    'T--': 'T--', 
    'R--':'ADV', 
    'PRD': 'PRD',
    'PRF': 'PRF',
    'PRP': 'PRP',
    'PRT': 'PRT',
    'PR-': 'PRD',
    'PRN': 'PRN',
    'W--': 'PRQ',
    'PRQ': 'PRQ',
    'PP1': 'PRP',
    'PS2': 'PRP',
    'PS3': 'PRF', 
    'G--':'PRF',
    'ASS':'ASS',
    'VSB': 'VSB',
    'VSP': 'VSP',
    'VBI': 'VBI',
    'VBL': 'VBL',
    'VBT': 'VBT',
    'VSA': 'VSA',
    'CO': 'CO', 
    'H--': 'H--',
    'M--': 'M--',
}


def parse_tagged_sentence(tagged_text):
    tokens = []
    for w in tagged_text.split():
        parts = w.rsplit('/', 1)  
        if len(parts) == 2:
            tokens.append((parts[0], parts[1]))
    return tokens

def map_tag(tag):
    return label_mapping.get(tag, tag)

def evaluate_tags(gpt_tags, stanza_tags, manual_tags):
    results = []
    len_gpt = len(gpt_tags)
    len_stanza = len(stanza_tags)
    len_manual = len(manual_tags)

    max_len = max(len_gpt, len_stanza, len_manual)

    for idx in range(max_len):
        gpt_tok, gpt_tag = gpt_tags[idx] if idx < len_gpt else (None, None)
        stanza_tok, stanza_tag = stanza_tags[idx] if idx < len_stanza else (None, None)
        manual_tok, manual_tag = manual_tags[idx] if idx < len_manual else (None, None)

        gpt_match = (gpt_tok == manual_tok) and (map_tag(gpt_tag) == map_tag(manual_tag))
        stanza_match = (stanza_tok == manual_tok) and (map_tag(stanza_tag) == map_tag(manual_tag))

        result = {
            'index': idx,
            'manual_token': manual_tok,
            'manual_tag': map_tag(manual_tag) if manual_tag else None,
            'gpt_token': gpt_tok,
            'gpt_tag': map_tag(gpt_tag) if gpt_tag else None,
            'stanza_token': stanza_tok,
            'stanza_tag': map_tag(stanza_tag) if stanza_tag else None,
            'gpt_correct': gpt_match,
            'stanza_correct': stanza_match
        }
        results.append(result)
    return results

for i, row in df.iterrows():
    gpt = parse_tagged_sentence(row['gpt'])
    stanza = parse_tagged_sentence(row['stanza'])
    manual = parse_tagged_sentence(row['manual'])

    evaluated = evaluate_tags(gpt, stanza, manual)

    print(f"\n=== Kalimat ke-{i+1} ===")
    for r in evaluated:
        print(f"Index {r['index']}: manual=({r['manual_token']}/{r['manual_tag']}), "
              f"gpt=({r['gpt_token']}/{r['gpt_tag']}) [{'✅' if r['gpt_correct'] else '❌'}], "
              f"stanza=({r['stanza_token']}/{r['stanza_tag']}) [{'✅' if r['stanza_correct'] else '❌'}]")
# Out:
# === Kalimat ke-1 ===
# Index 0: manual=(Bagian/NSD), gpt=(Bagian/NSD) [✅], stanza=(Bagian/NSD) [✅]
# Index 1: manual=(dari/ADV), gpt=(dari/ADV) [✅], stanza=(dari/ADV) [✅]
# Index 2: manual=(bidang/NSD), gpt=(bidang/NSD) [✅], stanza=(bidang/NSD) [✅]
# Index 3: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 4: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 5: manual=(membutuhkan/VSA), gpt=(membutuhkan/VSA) [✅], stanza=(membutuhkan/VSA) [✅]
# Index 6: manual=(penggunaan/NSD), gpt=(penggunaan/NSD) [✅], stanza=(penggunaan/NSD) [✅]
# Index 7: manual=(mikroskop/F--), gpt=(mikroskop/NSD) [❌], stanza=(mikroskop/F--) [✅]
# Index 8: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 9: manual=(sebagai/ADV), gpt=(sebagai/ADV) [✅], stanza=(sebagai/ADV) [✅]
# Index 10: manual=(contoh/NSD), gpt=(contoh/NSD) [✅], stanza=(contoh/NSD) [✅]
#
# === Kalimat ke-2 ===
# Index 0: manual=(Dalam/ADV), gpt=(Dalam/ADV) [✅], stanza=(Dalam/NSD) [❌]
# Index 1: manual=(studi/NSD), gpt=(studi/NSD) [✅], stanza=(studi/NSD) [✅]
# Index 2: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 3: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 4: manual=(penggunaan/NSB), gpt=(penggunaan/NSD) [❌], stanza=(penggunaan/NSD) [❌]
# Index 5: manual=(mikroskop/NSD), gpt=(mikroskop/F--) [❌], stanza=(mikroskop/F--) [❌]
# Index 6: manual=(diperlukan/VSP), gpt=(diperlukan/VSP) [✅], stanza=(diperlukan/VSP) [✅]
# Index 7: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 8: manual=(mempelajari/VBT), gpt=(mempelajari/VSA) [❌], stanza=(mempelajari/VSA) [❌]
# Index 9: manual=(hal/NSD), gpt=(hal/NSD) [✅], stanza=(hal/NSD) [✅]
# Index 10: manual=(seperti/ADV), gpt=(seperti/ADV) [✅], stanza=(seperti/ADV) [✅]
#
# === Kalimat ke-3 ===
# Index 0: manual=(Ilmu/NSD), gpt=(Ilmu/NSD) [✅], stanza=(Ilmu/NSD) [✅]
# Index 1: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(membutuhkan/VBT), gpt=(membutuhkan/VSA) [❌], stanza=(membutuhkan/VSA) [❌]
# Index 4: manual=(penggunaan/NSB), gpt=(penggunaan/NSD) [❌], stanza=(penggunaan/NSD) [❌]
# Index 5: manual=(mikroskop/NSD), gpt=(mikroskop/F--) [❌], stanza=(mikroskop/F--) [❌]
# Index 6: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 7: manual=(mengkaji/VBT), gpt=(mengkaji/VSA) [❌], stanza=(mengkaji/VSA) [❌]
# Index 8: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 9: manual=(sebagai/ADV), gpt=(sebagai/ADV) [✅], stanza=(sebagai/ADV) [✅]
# Index 10: manual=(contoh/NSD), gpt=(contoh/NSD) [✅], stanza=(contoh/NSD) [✅]
#
# === Kalimat ke-4 ===
# Index 0: manual=(Cabang/NSD), gpt=(Cabang/NSD) [✅], stanza=(Cabang/NSD) [✅]
# Index 1: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(mendorong/VBT), gpt=(mendorong/VSA) [❌], stanza=(mendorong/VSA) [❌]
# Index 4: manual=(peneliti/NSD), gpt=(peneliti/NSD) [✅], stanza=(peneliti/NSD) [✅]
# Index 5: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 6: manual=(menghasilkan/VBT), gpt=(menghasilkan/VSA) [❌], stanza=(menghasilkan/VSA) [❌]
# Index 7: manual=(bibit/NSD), gpt=(bibit/NSD) [✅], stanza=(bibit/NSD) [✅]
# Index 8: manual=(unggul/ADJ), gpt=(unggul/ADV) [❌], stanza=(unggul/ADV) [❌]
# Index 9: manual=(melalui/ADV), gpt=(melalui/ADV) [✅], stanza=(melalui/ADV) [✅]
# Index 10: manual=(hibridisasi/ADV), gpt=(hibridisasi/F--) [❌], stanza=(hibridisasi/F--) [❌]
# Index 11: manual=((/Z--), gpt=((/Z--) [✅], stanza=((/Z--) [✅]
# Index 12: manual=(persilangan/NSB), gpt=(persilangan/NSD) [❌], stanza=(persilangan/NSD) [❌]
# Index 13: manual=()/Z--), gpt=()/Z--) [✅], stanza=()/Z--) [✅]
#
# === Kalimat ke-5 ===
# Index 0: manual=(Cabang/NSD), gpt=(Cabang/NSD) [✅], stanza=(Cabang/NSD) [✅]
# Index 1: manual=(ilmu/NSD), gpt=(ilmu/NSD) [✅], stanza=(ilmu/NSD) [✅]
# Index 2: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 3: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 4: manual=(menjadi/VBT), gpt=(menjadi/VSA) [❌], stanza=(menjadi/VSA) [❌]
# Index 5: manual=(dasar/NSD), gpt=(dasar/NSD) [✅], stanza=(dasar/NSD) [✅]
# Index 6: manual=(bagi/ADV), gpt=(bagi/ADV) [✅], stanza=(bagi/ADV) [✅]
# Index 7: manual=(peneliti/NSD), gpt=(peneliti/NSD) [✅], stanza=(peneliti/NSD) [✅]
# Index 8: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 9: manual=(mengembangkan/VBT), gpt=(mengembangkan/VSA) [❌], stanza=(mengembangkan/VSA) [❌]
# Index 10: manual=(bibit/NSD), gpt=(bibit/NSD) [✅], stanza=(bibit/NSD) [✅]
# Index 11: manual=(unggul/ADJ), gpt=(unggul/ADV) [❌], stanza=(unggul/ADV) [❌]
# Index 12: manual=(melalui/ADV), gpt=(melalui/ADV) [✅], stanza=(melalui/ADV) [✅]
# Index 13: manual=(teknik/NSD), gpt=(teknik/NSD) [✅], stanza=(teknik/NSD) [✅]
# Index 14: manual=(persilangan/NSB), gpt=(persilangan/NSD) [❌], stanza=(persilangan/NSD) [❌]
#
# === Kalimat ke-6 ===
# Index 0: manual=(Bidang/NSD), gpt=(Bidang/NSD) [✅], stanza=(Bidang/NSD) [✅]
# Index 1: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(mendasari/VBT), gpt=(mendasari/VSA) [❌], stanza=(mendasari/VSA) [❌]
# Index 4: manual=(upaya/NSD), gpt=(upaya/NSD) [✅], stanza=(upaya/NSD) [✅]
# Index 5: manual=(para/DET), gpt=(para/PRF) [❌], stanza=(para/B--) [❌]
# Index 6: manual=(peneliti/NSD), gpt=(peneliti/NSD) [✅], stanza=(peneliti/NSD) [✅]
# Index 7: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 8: manual=(meningkatkan/VBT), gpt=(meningkatkan/VSA) [❌], stanza=(meningkatkan/VSA) [❌]
# Index 9: manual=(produksi/NSD), gpt=(produksi/NSD) [✅], stanza=(produksi/NSD) [✅]
# Index 10: manual=(pangan/NSD), gpt=(pangan/NSD) [✅], stanza=(pangan/NSD) [✅]
# Index 11: manual=(melalui/ADV), gpt=(melalui/ADV) [✅], stanza=(melalui/ADV) [✅]
# Index 12: manual=(pengembangan/NSB), gpt=(pengembangan/NSD) [❌], stanza=(pengembangan/NSD) [❌]
# Index 13: manual=(bibit/NSD), gpt=(bibit/NSD) [✅], stanza=(bibit/NSD) [✅]
# Index 14: manual=(unggul/ADJ), gpt=(unggul/ADV) [❌], stanza=(unggul/ADV) [❌]
# Index 15: manual=(menggunakan/VBT), gpt=(menggunakan/VSA) [❌], stanza=(menggunakan/VSA) [❌]
# Index 16: manual=(hibridisasi/NSD), gpt=(hibridisasi/F--) [❌], stanza=(hibridisasi/F--) [❌]
#
# === Kalimat ke-7 ===
# Index 0: manual=(Hal/NSD), gpt=(Hal/NSD) [✅], stanza=(Hal/NSD) [✅]
# Index 1: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 2: manual=(dipelajari/VSP), gpt=(dipelajari/VSP) [✅], stanza=(dipelajari/VSP) [✅]
# Index 3: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 4: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 5: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 6: manual=(mengembangkan/VBT), gpt=(mengembangkan/VSA) [❌], stanza=(mengembangkan/VSA) [❌]
# Index 7: manual=(obat/NSD), gpt=(obat/NSD) [✅], stanza=(obat/NSD) [✅]
# Index 8: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 9: manual=(flu/NSD), gpt=(flu/NSD) [✅], stanza=(flu/NSD) [✅]
# Index 10: manual=(burung/NSD), gpt=(burung/NSD) [✅], stanza=(burung/NSD) [✅]
# Index 11: manual=((/Z--), gpt=((/Z--) [✅], stanza=((/Z--) [✅]
# Index 12: manual=(SARS/NSD), gpt=(SARS/F--) [❌], stanza=(SARS/F--) [❌]
# Index 13: manual=()/Z--), gpt=()/Z--) [✅], stanza=()/Z--) [✅]
# Index 14: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-8 ===
# Index 0: manual=(Komponen/NSD), gpt=(Komponen/NSD) [✅], stanza=(Komponen/NSD) [✅]
# Index 1: manual=(studi/NSD), gpt=(studi/NSD) [✅], stanza=(studi/NSD) [✅]
# Index 2: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 3: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 4: manual=(diperlukan/VSP), gpt=(diperlukan/VSP) [✅], stanza=(diperlukan/VSP) [✅]
# Index 5: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 6: manual=(pengembangan/NSB), gpt=(pengembangan/NSD) [❌], stanza=(pengembangan/NSD) [❌]
# Index 7: manual=(obat/NSD), gpt=(obat/NSD) [✅], stanza=(obat/NSD) [✅]
# Index 8: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 9: manual=(flu/NSD), gpt=(flu/NSD) [✅], stanza=(flu/F--) [❌]
# Index 10: manual=(burung/NSD), gpt=(burung/NSD) [✅], stanza=(burung/NSD) [✅]
# Index 11: manual=((/Z--), gpt=((/Z--) [✅], stanza=((/Z--) [✅]
# Index 12: manual=(SARS/NSD), gpt=(SARS/F--) [❌], stanza=(SARS/F--) [❌]
# Index 13: manual=()/Z--), gpt=()/Z--) [✅], stanza=()/Z--) [✅]
# Index 14: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-9 ===
# Index 0: manual=(Aspek/NSD), gpt=(Aspek/NSD) [✅], stanza=(Aspek/NSD) [✅]
# Index 1: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(penting/ADJ), gpt=(penting/ADV) [❌], stanza=(penting/ADV) [❌]
# Index 4: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 5: manual=(upaya/NSD), gpt=(upaya/NSD) [✅], stanza=(upaya/NSD) [✅]
# Index 6: manual=(mengembangkan/VBT), gpt=(mengembangkan/VSA) [❌], stanza=(mengembangkan/VSA) [❌]
# Index 7: manual=(obat/NSD), gpt=(obat/NSD) [✅], stanza=(obat/NSD) [✅]
# Index 8: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 9: manual=(flu/NSD), gpt=(flu/NSD) [✅], stanza=(flu/NSD) [✅]
# Index 10: manual=(burung/NSD), gpt=(burung/NSD) [✅], stanza=(burung/NSD) [✅]
# Index 11: manual=((/Z--), gpt=((/Z--) [✅], stanza=((/Z--) [✅]
# Index 12: manual=(SARS/NSD), gpt=(SARS/F--) [❌], stanza=(SARS/F--) [❌]
# Index 13: manual=()/Z--), gpt=()/Z--) [✅], stanza=()/Z--) [✅]
# Index 14: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-10 ===
# Index 0: manual=(Ada/VBI), gpt=(Ada/VSA) [❌], stanza=(Ada/ADV) [❌]
# Index 1: manual=(sejumlah/DET), gpt=(sejumlah/O--) [❌], stanza=(sejumlah/B--) [❌]
# Index 2: manual=(kelompok/NUM), gpt=(kelompok/NSD) [❌], stanza=(kelompok/NSD) [❌]
# Index 3: manual=(belalang/NSD), gpt=(belalang/NSD) [✅], stanza=(belalang/NSD) [✅]
# Index 4: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 5: manual=(semut/NSD), gpt=(semut/NSD) [✅], stanza=(semut/NSD) [✅]
# Index 6: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 7: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 8: manual=(rumput/NSD), gpt=(rumput/NSD) [✅], stanza=(rumput/NSD) [✅]
# Index 9: manual=(sehingga/S--), gpt=(sehingga/S--) [✅], stanza=(sehingga/S--) [✅]
# Index 10: manual=(terbentuk/VSP), gpt=(terbentuk/VSP) [✅], stanza=(terbentuk/VSP) [✅]
#
# === Kalimat ke-11 ===
# Index 0: manual=(Terdapat/VBI), gpt=(Terdapat/VSA) [❌], stanza=(Terdapat/VSP) [❌]
# Index 1: manual=(kumpulan/NUM), gpt=(kumpulan/NSD) [❌], stanza=(kumpulan/NSD) [❌]
# Index 2: manual=(kelompok/NUM), gpt=(kelompok/NSD) [❌], stanza=(kelompok/NSD) [❌]
# Index 3: manual=(belalang/NSD), gpt=(belalang/NSD) [✅], stanza=(belalang/NSD) [✅]
# Index 4: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 5: manual=(semut/NSD), gpt=(semut/NSD) [✅], stanza=(semut/NSD) [✅]
# Index 6: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 7: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 8: manual=(rumput/NSD), gpt=(rumput/NSD) [✅], stanza=(rumput/NSD) [✅]
# Index 9: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 10: manual=(akan/ADV), gpt=(akan/B--) [❌], stanza=(akan/M--) [❌]
# Index 11: manual=(membentuk/VBT), gpt=(membentuk/VSA) [❌], stanza=(membentuk/VSA) [❌]
#
# === Kalimat ke-12 ===
# Index 0: manual=(Di/ADV), gpt=(Di/ADV) [✅], stanza=(Di/ADV) [✅]
# Index 1: manual=(suatu/NUM), gpt=(suatu/NSD) [❌], stanza=(suatu/B--) [❌]
# Index 2: manual=(tempat/NSD), gpt=(tempat/NSB) [❌], stanza=(tempat/NSD) [✅]
# Index 3: manual=(terdapat/VBI), gpt=(terdapat/VSA) [❌], stanza=(terdapat/VSP) [❌]
# Index 4: manual=(kumpulan/NUM), gpt=(kumpulan/NSB) [❌], stanza=(kumpulan/NSD) [❌]
# Index 5: manual=(kelompok/NUM), gpt=(kelompok/NSB) [❌], stanza=(kelompok/NSD) [❌]
# Index 6: manual=(belalang/NSD), gpt=(belalang/NSB) [❌], stanza=(belalang/NSD) [✅]
# Index 7: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 8: manual=(kelompok/NUM), gpt=(kelompok/NSB) [❌], stanza=(kelompok/NSD) [❌]
# Index 9: manual=(semut/NSD), gpt=(semut/NSB) [❌], stanza=(semut/NSD) [✅]
# Index 10: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 11: manual=(kelompok/NUM), gpt=(kelompok/NSB) [❌], stanza=(kelompok/NSD) [❌]
# Index 12: manual=(rumput/NSD), gpt=(rumput/NSB) [❌], stanza=(rumput/NSD) [✅]
# Index 13: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 14: manual=(Kumpulan/NUM), gpt=(Kumpulan/NSB) [❌], stanza=(Kumpulan/NSD) [❌]
# Index 15: manual=(kelompok/NUM), gpt=(kelompok/NSB) [❌], stanza=(kelompok/NSD) [❌]
# Index 16: manual=(tersebut/PRD), gpt=(tersebut/PRN) [❌], stanza=(tersebut/B--) [❌]
# Index 17: manual=(akan/ADV), gpt=(akan/T--) [❌], stanza=(akan/M--) [❌]
# Index 18: manual=(membentuk/VBT), gpt=(membentuk/VSA) [❌], stanza=(membentuk/VSA) [❌]
#
# === Kalimat ke-13 ===
# Index 0: manual=(Pilih/VSA), gpt=(Pilihlah/VSA) [❌], stanza=(Pilih/VSA) [✅]
# Index 1: manual=(lah/T--), gpt=(PAD/PAD) [❌], stanza=(lah/T--) [✅]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(tidak/ADV), gpt=(tidak/B--) [❌], stanza=(tidak/PRF) [❌]
# Index 4: manual=(termasuk/VBI), gpt=(termasuk/VSA) [❌], stanza=(termasuk/ADV) [❌]
# Index 5: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 6: manual=(persiapan/NSD), gpt=(persiapan/NSD) [✅], stanza=(persiapan/NSD) [✅]
# Index 7: manual=(sebelum/ADV), gpt=(sebelum/ADV) [✅], stanza=(sebelum/S--) [❌]
# Index 8: manual=(melakukan/VBT), gpt=(melakukan/VSA) [❌], stanza=(melakukan/VSA) [❌]
# Index 9: manual=(penelitian/NSD), gpt=(penelitian/NSD) [✅], stanza=(penelitian/NSD) [✅]
# Index 10: manual=(ilmiah/ADJ), gpt=(ilmiah/ADV) [❌], stanza=(ilmiah/ADV) [❌]
#
# === Kalimat ke-14 ===
# Index 0: manual=(Pilih/VSA), gpt=(Pilihlah/VSA) [❌], stanza=(Pilih/VSA) [✅]
# Index 1: manual=(lah/T--), gpt=(PAD/PAD) [❌], stanza=(lah/T--) [✅]
# Index 2: manual=(mana/PRQ), gpt=(mana/Y--) [❌], stanza=(mana/NSD) [❌]
# Index 3: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 4: manual=(bukan/ADV), gpt=(bukan/B--) [❌], stanza=(bukan/PRF) [❌]
# Index 5: manual=(termasuk/VBI), gpt=(termasuk/VSA) [❌], stanza=(termasuk/ADV) [❌]
# Index 6: manual=(hal/NSD), gpt=(hal/NSD) [✅], stanza=(hal/NSD) [✅]
# Index 7: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 8: manual=(disiapkan/VSP), gpt=(disiapkan/VSP) [✅], stanza=(disiapkan/VSP) [✅]
# Index 9: manual=(sebelum/ADV), gpt=(sebelum/ADV) [✅], stanza=(sebelum/S--) [❌]
# Index 10: manual=(melakukan/VBT), gpt=(melakukan/VSA) [❌], stanza=(melakukan/VSA) [❌]
# Index 11: manual=(penelitian/NSD), gpt=(penelitian/NSD) [✅], stanza=(penelitian/NSD) [✅]
# Index 12: manual=(ilmiah/ADJ), gpt=(ilmiah/ADV) [❌], stanza=(ilmiah/ADV) [❌]
#
# === Kalimat ke-15 ===
# Index 0: manual=(Mana/PRQ), gpt=(Mana/Y--) [❌], stanza=(Mana/NSD) [❌]
# Index 1: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 2: manual=(tidak/ADV), gpt=(tidak/B--) [❌], stanza=(tidak/PRF) [❌]
# Index 3: manual=(menjadi/VBT), gpt=(menjadi/VSA) [❌], stanza=(menjadi/VSA) [❌]
# Index 4: manual=(bagian/NSD), gpt=(bagian/NSD) [✅], stanza=(bagian/NSD) [✅]
# Index 5: manual=(dari/ADV), gpt=(dari/ADV) [✅], stanza=(dari/ADV) [✅]
# Index 6: manual=(persiapan/NSB), gpt=(persiapan/NSD) [❌], stanza=(persiapan/NSD) [❌]
# Index 7: manual=(sebelum/ADV), gpt=(sebelum/ADV) [✅], stanza=(sebelum/S--) [❌]
# Index 8: manual=(melakukan/VBT), gpt=(melakukan/VSA) [❌], stanza=(melakukan/VSA) [❌]
# Index 9: manual=(penelitian/NSD), gpt=(penelitian/NSD) [✅], stanza=(penelitian/NSD) [✅]
# Index 10: manual=(ilmiah/ADJ), gpt=(ilmiah/ADV) [❌], stanza=(ilmiah/ADV) [❌]
#
# === Kalimat ke-16 ===
# Index 0: manual=(Di/ADV), gpt=(Di/ADV) [✅], stanza=(Di/ADV) [✅]
# Index 1: manual=(antara/ADV), gpt=(antara/ADV) [✅], stanza=(antara/ADV) [✅]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(berikut/ADJ), gpt=(berikut/NSD) [❌], stanza=(berikut/VSA) [❌]
# Index 4: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 5: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 6: manual=(kegiatan/NSD), gpt=(kegiatan/NSD) [✅], stanza=(kegiatan/NSD) [✅]
# Index 7: manual=(mana/PRQ), gpt=(manakah/H--) [❌], stanza=(mana/PRQ) [✅]
# Index 8: manual=(kah/PRT), gpt=(PAD/PAD) [❌], stanza=(kah/T--) [❌]
# Index 9: manual=(bukan/ADV), gpt=(bukan/B--) [❌], stanza=(bukan/PRF) [❌]
# Index 10: manual=(termasuk/VBI), gpt=(termasuk/VSA) [❌], stanza=(termasuk/ADV) [❌]
# Index 11: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 12: manual=(pengamatan/NSB), gpt=(pengamatan/NSD) [❌], stanza=(pengamatan/NSD) [❌]
#
# === Kalimat ke-17 ===
# Index 0: manual=(Mana/PRQ), gpt=(Mana/Y--) [❌], stanza=(Mana/NSD) [❌]
# Index 1: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 2: manual=(antara/ADV), gpt=(antara/ADV) [✅], stanza=(antara/ADV) [✅]
# Index 3: manual=(berikut/ADJ), gpt=(berikut/NSD) [❌], stanza=(berikut/VSA) [❌]
# Index 4: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 5: manual=(bukan/ADV), gpt=(bukan/B--) [❌], stanza=(bukan/PRF) [❌]
# Index 6: manual=(merupakan/VBL), gpt=(merupakan/VSA) [❌], stanza=(merupakan/O--) [❌]
# Index 7: manual=(kegiatan/NSD), gpt=(kegiatan/NSD) [✅], stanza=(kegiatan/NSD) [✅]
# Index 8: manual=(pengamatan/NSB), gpt=(pengamatan/NSD) [❌], stanza=(pengamatan/NSD) [❌]
#
# === Kalimat ke-18 ===
# Index 0: manual=(Berikut/ADJ), gpt=(Berikut/NSD) [❌], stanza=(Berikut/VSA) [❌]
# Index 1: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(bukan/ADV), gpt=(bukan/B--) [❌], stanza=(bukan/PRF) [❌]
# Index 4: manual=(merupakan/VBL), gpt=(merupakan/VSA) [❌], stanza=(merupakan/O--) [❌]
# Index 5: manual=(kegiatan/NSD), gpt=(kegiatan/NSD) [✅], stanza=(kegiatan/NSD) [✅]
# Index 6: manual=(observasi/NSD), gpt=(observasi/NSD) [✅], stanza=(observasi/NSD) [✅]
# Index 7: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-19 ===
# Index 0: manual=(Pada/ADV), gpt=(Pada/ADV) [✅], stanza=(Pada/ADV) [✅]
# Index 1: manual=(penulisan/NSB), gpt=(penulisan/NSD) [❌], stanza=(penulisan/NSD) [❌]
# Index 2: manual=(makalah/NSD), gpt=(makalah/NSD) [✅], stanza=(makalah/NSD) [✅]
# Index 3: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 4: manual=(terdapat/VBI), gpt=(terdapat/VSA) [❌], stanza=(terdapat/VSP) [❌]
# Index 5: manual=(bagian/NSD), gpt=(bagian/NSD) [✅], stanza=(bagian/NSD) [✅]
# Index 6: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 7: manual=(membahas/VBT), gpt=(membahas/VSA) [❌], stanza=(membahas/VSA) [❌]
# Index 8: manual=(pengolahan/NSB), gpt=(pengolahan/NSD) [❌], stanza=(pengolahan/NSD) [❌]
# Index 9: manual=(data/NSD), gpt=(data/NSD) [✅], stanza=(data/NSD) [✅]
# Index 10: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 11: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
# Index 12: manual=(sebagai/ADV), gpt=(sebagai/ADV) [✅], stanza=(sebagai/ADV) [✅]
#
# === Kalimat ke-20 ===
# Index 0: manual=(Pada/ADV), gpt=(Pada/ADV) [✅], stanza=(Pada/ADV) [✅]
# Index 1: manual=(penulisan/NSB), gpt=(penulisan/NSD) [❌], stanza=(penulisan/NSD) [❌]
# Index 2: manual=(makalah/NSD), gpt=(makalah/NSD) [✅], stanza=(makalah/NSD) [✅]
# Index 3: manual=(terdapat/VBI), gpt=(terdapat/VSA) [❌], stanza=(terdapat/VSP) [❌]
# Index 4: manual=(bab/NSD), gpt=(bab/NSD) [✅], stanza=(bab/NSD) [✅]
# Index 5: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 6: manual=(membahas/VBT), gpt=(membahas/VSA) [❌], stanza=(membahas/VSA) [❌]
# Index 7: manual=(pengolahan/NSB), gpt=(pengolahan/NSD) [❌], stanza=(pengolahan/NSD) [❌]
# Index 8: manual=(data/NSD), gpt=(data/NSD) [✅], stanza=(data/NSD) [✅]
# Index 9: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 10: manual=(yaitu/O--), gpt=(yaitu/ADV) [❌], stanza=(yaitu/O--) [✅]
# Index 11: manual=(bagian/NSD), gpt=(bagian/NSD) [✅], stanza=(bagian/NSD) [✅]
#
# === Kalimat ke-21 ===
# Index 0: manual=(Saat/NSD), gpt=(Saat/ADV) [❌], stanza=(Saat/NSD) [✅]
# Index 1: manual=(Anda/PRP), gpt=(Anda/PRF) [❌], stanza=(Anda/PRP) [✅]
# Index 2: manual=(menulis/VBT), gpt=(menulis/VSA) [❌], stanza=(menulis/VSA) [❌]
# Index 3: manual=(makalah/NSD), gpt=(makalah/NSD) [✅], stanza=(makalah/NSD) [✅]
# Index 4: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 5: manual=(bagian/NSD), gpt=(bagian/NSD) [✅], stanza=(bagian/NSD) [✅]
# Index 6: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 7: manual=(membahas/VBT), gpt=(membahas/VSA) [❌], stanza=(membahas/VSA) [❌]
# Index 8: manual=(pengolahan/NSB), gpt=(pengolahan/NSD) [❌], stanza=(pengolahan/NSD) [❌]
# Index 9: manual=(data/NSD), gpt=(data/NSD) [✅], stanza=(data/NSD) [✅]
# Index 10: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
#
# === Kalimat ke-22 ===
# Index 0: manual=(Sampai/ADV), gpt=(Sampai/ADV) [✅], stanza=(Sampai/ADV) [✅]
# Index 1: manual=(saat/NSD), gpt=(saat/NSD) [✅], stanza=(saat/NSD) [✅]
# Index 2: manual=(ini/PRD), gpt=(ini/ADV) [❌], stanza=(ini/B--) [❌]
# Index 3: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 4: manual=(tidak/ADV), gpt=(tidak/ADV) [✅], stanza=(tidak/PRF) [❌]
# Index 5: manual=(ada/VBI), gpt=(ada/VSB) [❌], stanza=(ada/ADV) [❌]
# Index 6: manual=(obat/NSD), gpt=(obat/NSB) [❌], stanza=(obat/NSD) [✅]
# Index 7: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 8: manual=(penyakit/NSD), gpt=(penyakit/NSB) [❌], stanza=(penyakit/NSD) [✅]
# Index 9: manual=(AIDS/F--), gpt=(AIDS/NSB) [❌], stanza=(AIDS/F--) [✅]
# Index 10: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 11: manual=(Para/DET), gpt=(Para/PRN) [❌], stanza=(Para/B--) [❌]
# Index 12: manual=(ahli/NSD), gpt=(ahli/NSB) [❌], stanza=(ahli/NSD) [✅]
# Index 13: manual=(melakukan/VBT), gpt=(melakukan/VSA) [❌], stanza=(melakukan/VSA) [❌]
# Index 14: manual=(penelitian/NSD), gpt=(penelitian/NSB) [❌], stanza=(penelitian/NSD) [✅]
# Index 15: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 16: manual=(memahami/VBT), gpt=(memahami/VSA) [❌], stanza=(memahami/VSA) [❌]
# Index 17: manual=(aktivitas/NSD), gpt=(aktivitas/NSB) [❌], stanza=(aktivitas/NSD) [✅]
# Index 18: manual=(Virus/NSD), gpt=(Virus/NSB) [❌], stanza=(Virus/F--) [❌]
# Index 19: manual=(HIV/NSD), gpt=(HIV/NSB) [❌], stanza=(HIV/F--) [❌]
# Index 20: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 21: manual=(tingkat/NSD), gpt=(tingkat/NSB) [❌], stanza=(tingkat/NSD) [✅]
# Index 22: manual=(organisasi/NSD), gpt=(organisasi/NSB) [❌], stanza=(organisasi/NSD) [✅]
# Index 23: manual=(kehidupan/NSD), gpt=(kehidupan/NSB) [❌], stanza=(kehidupan/NSD) [✅]
# Index 24: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 25: manual=(yaitu/O--), gpt=(yaitu/ADV) [❌], stanza=(yaitu/O--) [✅]
#
# === Kalimat ke-23 ===
# Index 0: manual=(Saat/NSD), gpt=(Saat/ADV) [❌], stanza=(Saat/NSD) [✅]
# Index 1: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 2: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 3: manual=(belum/ADV), gpt=(belum/B--) [❌], stanza=(belum/PRF) [❌]
# Index 4: manual=(ada/VBI), gpt=(ada/VSA) [❌], stanza=(ada/ADV) [❌]
# Index 5: manual=(obat/NSD), gpt=(obat/NSD) [✅], stanza=(obat/NSD) [✅]
# Index 6: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 7: manual=(efektif/ADJ), gpt=(efektif/ADV) [❌], stanza=(efektif/ADV) [❌]
# Index 8: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 9: manual=(AIDS/NSD), gpt=(AIDS/F--) [❌], stanza=(AIDS/F--) [❌]
# Index 10: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 11: manual=(Ahli/NSD), gpt=(Ahli/NSD) [✅], stanza=(Ahli/NSD) [✅]
# Index 12: manual=(sedang/ADV), gpt=(sedang/B--) [❌], stanza=(sedang/D--) [❌]
# Index 13: manual=(melakukan/VBT), gpt=(melakukan/VSA) [❌], stanza=(melakukan/VSA) [❌]
# Index 14: manual=(penelitian/NSD), gpt=(penelitian/NSD) [✅], stanza=(penelitian/NSD) [✅]
# Index 15: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 16: manual=(memahami/VBT), gpt=(memahami/VSA) [❌], stanza=(memahami/VSA) [❌]
# Index 17: manual=(aktivitas/NSD), gpt=(aktivitas/NSD) [✅], stanza=(aktivitas/NSD) [✅]
# Index 18: manual=(Virus/NSD), gpt=(Virus/F--) [❌], stanza=(Virus/F--) [❌]
# Index 19: manual=(HIV/NSD), gpt=(HIV/F--) [❌], stanza=(HIV/F--) [❌]
# Index 20: manual=(pada/ADV), gpt=(pada/ADV) [✅], stanza=(pada/ADV) [✅]
# Index 21: manual=(tingkat/NSD), gpt=(tingkat/NSD) [✅], stanza=(tingkat/NSD) [✅]
# Index 22: manual=(kehidupan/NSD), gpt=(kehidupan/NSD) [✅], stanza=(kehidupan/NSD) [✅]
# Index 23: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 24: manual=(yakni/O--), gpt=(yakni/ADV) [❌], stanza=(yakni/O--) [✅]
#
# === Kalimat ke-24 ===
# Index 0: manual=(Sampai/ADV), gpt=(Sampai/ADV) [✅], stanza=(Sampai/ADV) [✅]
# Index 1: manual=(sekarang/NSD), gpt=(sekarang/T--) [❌], stanza=(sekarang/D--) [❌]
# Index 2: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 3: manual=(belum/ADV), gpt=(belum/B--) [❌], stanza=(belum/PRF) [❌]
# Index 4: manual=(ada/VBI), gpt=(ada/VSA) [❌], stanza=(ada/ADV) [❌]
# Index 5: manual=(obat/NSD), gpt=(obat/NSD) [✅], stanza=(obat/NSD) [✅]
# Index 6: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 7: manual=(tersedia/VBI), gpt=(tersedia/ADV) [❌], stanza=(tersedia/ADV) [❌]
# Index 8: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 9: manual=(AIDS/NSD), gpt=(AIDS/F--) [❌], stanza=(AIDS/F--) [❌]
# Index 10: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 11: manual=(Penelitian/NSD), gpt=(Penelitian/NSD) [✅], stanza=(Penelitian/NSD) [✅]
# Index 12: manual=(sedang/ADV), gpt=(sedang/B--) [❌], stanza=(sedang/D--) [❌]
# Index 13: manual=(dilakukan/VSP), gpt=(dilakukan/VSP) [✅], stanza=(dilakukan/VSP) [✅]
# Index 14: manual=(oleh/ADV), gpt=(oleh/ADV) [✅], stanza=(oleh/ADV) [✅]
# Index 15: manual=(para/DET), gpt=(para/PRF) [❌], stanza=(para/B--) [❌]
# Index 16: manual=(ahli/NSD), gpt=(ahli/NSD) [✅], stanza=(ahli/NSD) [✅]
# Index 17: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 18: manual=(memahami/VBT), gpt=(memahami/VSA) [❌], stanza=(memahami/VSA) [❌]
# Index 19: manual=(aktivitas/NSD), gpt=(aktivitas/NSD) [✅], stanza=(aktivitas/NSD) [✅]
# Index 20: manual=(Virus/NSD), gpt=(Virus/F--) [❌], stanza=(Virus/F--) [❌]
# Index 21: manual=(HIV/NSD), gpt=(HIV/F--) [❌], stanza=(HIV/F--) [❌]
# Index 22: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 23: manual=(tingkat/NSD), gpt=(tingkat/NSD) [✅], stanza=(tingkat/NSD) [✅]
# Index 24: manual=(organisasi/NSD), gpt=(organisasi/NSD) [✅], stanza=(organisasi/NSD) [✅]
# Index 25: manual=(kehidupan/NSD), gpt=(kehidupan/NSD) [✅], stanza=(kehidupan/NSD) [✅]
# Index 26: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 27: manual=(yaitu/O--), gpt=(yaitu/ADV) [❌], stanza=(yaitu/O--) [✅]
#
# === Kalimat ke-25 ===
# Index 0: manual=(Dinding/NSD), gpt=(Dinding/NSD) [✅], stanza=(Dinding/NSD) [✅]
# Index 1: manual=(sel/NSD), gpt=(sel/NSD) [✅], stanza=(sel/NSD) [✅]
# Index 2: manual=(bakteri/NSD), gpt=(bakteri/NSD) [✅], stanza=(bakteri/NSD) [✅]
# Index 3: manual=(terbuat/VSP), gpt=(terbuat/VSP) [✅], stanza=(terbuat/VSP) [✅]
# Index 4: manual=(dari/ADV), gpt=(dari/ADV) [✅], stanza=(dari/ADV) [✅]
# Index 5: manual=(campuran/NSD), gpt=(campuran/NSD) [✅], stanza=(campuran/NSD) [✅]
# Index 6: manual=(polisakarida/NSD), gpt=(polisakarida/F--) [❌], stanza=(polisakarida/F--) [❌]
# Index 7: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 8: manual=(protein/NSD), gpt=(protein/F--) [❌], stanza=(protein/NSD) [✅]
# Index 9: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 10: manual=(Campuran/NSD), gpt=(Campuran/NSD) [✅], stanza=(Campuran/NSD) [✅]
# Index 11: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 12: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
# Index 13: manual=(dengan/ADV), gpt=(dengan/ADV) [✅], stanza=(dengan/ADV) [✅]
#
# === Kalimat ke-26 ===
# Index 0: manual=(Dinding/NSD), gpt=(Dinding/NSD) [✅], stanza=(Dinding/NSD) [✅]
# Index 1: manual=(sel/NSD), gpt=(sel/NSD) [✅], stanza=(sel/NSD) [✅]
# Index 2: manual=(bakteri/NSD), gpt=(bakteri/NSD) [✅], stanza=(bakteri/NSD) [✅]
# Index 3: manual=(terbentuk/VSP), gpt=(terbentuk/VSP) [✅], stanza=(terbentuk/VSP) [✅]
# Index 4: manual=(dari/ADV), gpt=(dari/ADV) [✅], stanza=(dari/ADV) [✅]
# Index 5: manual=(kombinasi/NSD), gpt=(kombinasi/NSD) [✅], stanza=(kombinasi/NSD) [✅]
# Index 6: manual=(polisakarida/NSD), gpt=(polisakarida/F--) [❌], stanza=(polisakarida/F--) [❌]
# Index 7: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 8: manual=(protein/NSD), gpt=(protein/F--) [❌], stanza=(protein/NSD) [✅]
# Index 9: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 10: manual=(Kombinasi/NSD), gpt=(Kombinasi/NSD) [✅], stanza=(Kombinasi/NSD) [✅]
# Index 11: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 12: manual=(dikenal/VSP), gpt=(dikenal/VSP) [✅], stanza=(dikenal/VSP) [✅]
# Index 13: manual=(sebagai/ADV), gpt=(sebagai/ADV) [✅], stanza=(sebagai/ADV) [✅]
#
# === Kalimat ke-27 ===
# Index 0: manual=(Dinding/NSD), gpt=(Dinding/NSD) [✅], stanza=(Dinding/NSD) [✅]
# Index 1: manual=(sel/NSD), gpt=(sel/NSD) [✅], stanza=(sel/NSD) [✅]
# Index 2: manual=(bakteri/NSD), gpt=(bakteri/NSD) [✅], stanza=(bakteri/NSD) [✅]
# Index 3: manual=(terdiri/VBI), gpt=(terdiri/VSA) [❌], stanza=(terdiri/VSP) [❌]
# Index 4: manual=(dari/ADV), gpt=(dari/ADV) [✅], stanza=(dari/ADV) [✅]
# Index 5: manual=(polisakarida/NSD), gpt=(polisakarida/F--) [❌], stanza=(polisakarida/F--) [❌]
# Index 6: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 7: manual=(protein/NSD), gpt=(protein/F--) [❌], stanza=(protein/NSD) [✅]
# Index 8: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 9: manual=(bergabung/VBI), gpt=(bergabung/VSA) [❌], stanza=(bergabung/VSA) [❌]
# Index 10: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 11: manual=(Gabungan/NSD), gpt=(Gabungan/NSD) [✅], stanza=(Gabungan/NSD) [✅]
# Index 12: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 13: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
#
# === Kalimat ke-28 ===
# Index 0: manual=(Film/NSD), gpt=(Film/NSD) [✅], stanza=(Film/NSD) [✅]
# Index 1: manual=(Hollywood/NSD), gpt=(Hollywood/F--) [❌], stanza=(Hollywood/F--) [❌]
# Index 2: manual=(terkenal/ADJ), gpt=(terkenal/ADV) [❌], stanza=(terkenal/VSP) [❌]
# Index 3: manual=(Jurassic/F--), gpt=(Jurassic/F--) [✅], stanza=(Jurassic/F--) [✅]
# Index 4: manual=(Park/F--), gpt=(Park/F--) [✅], stanza=(Park/F--) [✅]
# Index 5: manual=(bercerita/VBI), gpt=(bercerita/VSA) [❌], stanza=(bercerita/VSA) [❌]
# Index 6: manual=(tentang/ADV), gpt=(tentang/ADV) [✅], stanza=(tentang/VSA) [❌]
# Index 7: manual=(kehidupan/NSD), gpt=(kehidupan/NSD) [✅], stanza=(kehidupan/NSD) [✅]
# Index 8: manual=(hewan/NSD), gpt=(hewan/NSD) [✅], stanza=(hewan/NSD) [✅]
# Index 9: manual=(purba/ADJ), gpt=(purba/ADV) [❌], stanza=(purba/ADV) [❌]
# Index 10: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 11: manual=(Ilmu/NSD), gpt=(Ilmu/NSD) [✅], stanza=(Ilmu/NSD) [✅]
# Index 12: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 13: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 14: manual=(digunakan/VSP), gpt=(digunakan/VSP) [✅], stanza=(digunakan/VSP) [✅]
# Index 15: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-29 ===
# Index 0: manual=(Pembuatan/NSB), gpt=(Pembuatan/NSD) [❌], stanza=(Pembuatan/NSD) [❌]
# Index 1: manual=(film/NSD), gpt=(film/NSD) [✅], stanza=(film/NSD) [✅]
# Index 2: manual=(Jurassic/F--), gpt=(Jurassic/F--) [✅], stanza=(Jurassic/F--) [✅]
# Index 3: manual=(Park/F--), gpt=(Park/F--) [✅], stanza=(Park/F--) [✅]
# Index 4: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 5: manual=(terkenal/ADJ), gpt=(terkenal/ADV) [❌], stanza=(terkenal/VSP) [❌]
# Index 6: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 7: manual=(Hollywood/NSD), gpt=(Hollywood/F--) [❌], stanza=(Hollywood/F--) [❌]
# Index 8: manual=(menceritakan/VBT), gpt=(menceritakan/VSA) [❌], stanza=(menceritakan/VSA) [❌]
# Index 9: manual=(tentang/ADV), gpt=(tentang/ADV) [✅], stanza=(tentang/VSA) [❌]
# Index 10: manual=(hewan/NSD), gpt=(hewan-hewan/NSD) [❌], stanza=(hewan-hewan/NSD) [❌]
# Index 11: manual=(-/Z--), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 12: manual=(hewan/NSD), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 13: manual=(purba/NSD), gpt=(purba/ADV) [❌], stanza=(purba/ADV) [❌]
# Index 14: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 15: manual=(Ilmu/NSD), gpt=(Ilmu/NSD) [✅], stanza=(Ilmu/NSD) [✅]
# Index 16: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 17: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 18: manual=(terlibat/VBL), gpt=(terlibat/VSP) [❌], stanza=(terlibat/VSP) [❌]
# Index 19: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-30 ===
# Index 0: manual=(Jurassic/F--), gpt=(Jurassic/F--) [✅], stanza=(Jurassic/F--) [✅]
# Index 1: manual=(Park/F--), gpt=(Park/F--) [✅], stanza=(Park/F--) [✅]
# Index 2: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 3: manual=(film/NSD), gpt=(film/NSD) [✅], stanza=(film/NSD) [✅]
# Index 4: manual=(Hollywood/NSD), gpt=(Hollywood/F--) [❌], stanza=(Hollywood/F--) [❌]
# Index 5: manual=(terkenal/ADJ), gpt=(terkenal/ADV) [❌], stanza=(terkenal/VSP) [❌]
# Index 6: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 7: manual=(mengisahkan/VBT), gpt=(mengisahkan/VSA) [❌], stanza=(mengisahkan/VSA) [❌]
# Index 8: manual=(kehidupan/NSD), gpt=(kehidupan/NSD) [✅], stanza=(kehidupan/NSD) [✅]
# Index 9: manual=(hewan/NSD), gpt=(hewan/NSD) [✅], stanza=(hewan/NSD) [✅]
# Index 10: manual=(purba/ADJ), gpt=(purba/ADV) [❌], stanza=(purba/ADV) [❌]
# Index 11: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 12: manual=(Ilmu/NSD), gpt=(Ilmu/NSD) [✅], stanza=(Ilmu/NSD) [✅]
# Index 13: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 14: manual=(yang/Z--), gpt=(yang/S--) [❌], stanza=(yang/S--) [❌]
# Index 15: manual=(berperan/VBI), gpt=(berperan/VSA) [❌], stanza=(berperan/VSA) [❌]
# Index 16: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-31 ===
# Index 0: manual=(Manfaat/NSD), gpt=(Manfaat/NSD) [✅], stanza=(Manfaat/NSD) [✅]
# Index 1: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 2: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 3: manual=(bidang/NSD), gpt=(bidang/NSD) [✅], stanza=(bidang/NSD) [✅]
# Index 4: manual=(peternakan/NSD), gpt=(peternakan/NSD) [✅], stanza=(peternakan/NSD) [✅]
# Index 5: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-32 ===
# Index 0: manual=(Berikut/ADJ), gpt=(Berikut/NSD) [❌], stanza=(Berikut/VSA) [❌]
# Index 1: manual=(manfaat/NSD), gpt=(manfaat/NSD) [✅], stanza=(manfaat/NSD) [✅]
# Index 2: manual=(biologi/NSD), gpt=(biologi/NSD) [✅], stanza=(biologi/NSD) [✅]
# Index 3: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 4: manual=(bidang/NSD), gpt=(bidang/NSD) [✅], stanza=(bidang/NSD) [✅]
# Index 5: manual=(peternakan/NSD), gpt=(peternakan/NSD) [✅], stanza=(peternakan/NSD) [✅]
# Index 6: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-33 ===
# Index 0: manual=(Biologi/NSD), gpt=(Biologi/NSD) [✅], stanza=(Biologi/NSD) [✅]
# Index 1: manual=(memberikan/VBT), gpt=(memberikan/VSA) [❌], stanza=(memberikan/VSA) [❌]
# Index 2: manual=(manfaat/NSD), gpt=(manfaat/NSD) [✅], stanza=(manfaat/NSD) [✅]
# Index 3: manual=(berikut/ADJ), gpt=(berikut/NSD) [❌], stanza=(berikut/VSA) [❌]
# Index 4: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 5: manual=(peternakan/NSD), gpt=(peternakan/NSD) [✅], stanza=(peternakan/NSD) [✅]
#
# === Kalimat ke-34 ===
# Index 0: manual=(Peneliti/NSD), gpt=(Peneliti/NSD) [✅], stanza=(Peneliti/NSD) [✅]
# Index 1: manual=(mengamati/VBT), gpt=(mengamati/VSA) [❌], stanza=(mengamati/VSA) [❌]
# Index 2: manual=(perilaku/NSD), gpt=(perilaku/NSD) [✅], stanza=(perilaku/NSD) [✅]
# Index 3: manual=(harimau/NSD), gpt=(harimau/NSD) [✅], stanza=(harimau/F--) [❌]
# Index 4: manual=(Sumatera/NSD), gpt=(Sumatera/F--) [❌], stanza=(Sumatera/NSD) [✅]
# Index 5: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 6: manual=(Pengamatan/NSD), gpt=(Pengamatan/NSD) [✅], stanza=(Pengamatan/NSD) [✅]
# Index 7: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 8: manual=(dilakukan/VSP), gpt=(dilakukan/VSP) [✅], stanza=(dilakukan/VSP) [✅]
# Index 9: manual=(pada/ADV), gpt=(pada/ADV) [✅], stanza=(pada/ADV) [✅]
# Index 10: manual=(tingkat/NSD), gpt=(tingkat/NSD) [✅], stanza=(tingkat/NSD) [✅]
#
# === Kalimat ke-35 ===
# Index 0: manual=(Sekelompok/NUM), gpt=(Sekelompok/NSD) [❌], stanza=(Sekelompok/ADV) [❌]
# Index 1: manual=(peneliti/NSD), gpt=(peneliti/NSD) [✅], stanza=(peneliti/NSD) [✅]
# Index 2: manual=(melakukan/VBT), gpt=(melakukan/VSA) [❌], stanza=(melakukan/VSA) [❌]
# Index 3: manual=(pengamatan/NSD), gpt=(pengamatan/NSD) [✅], stanza=(pengamatan/NSD) [✅]
# Index 4: manual=(terhadap/ADV), gpt=(terhadap/ADV) [✅], stanza=(terhadap/ADV) [✅]
# Index 5: manual=(perilaku/NSD), gpt=(perilaku/NSD) [✅], stanza=(perilaku/NSD) [✅]
# Index 6: manual=(sekumpulan/NUM), gpt=(sekumpulan/NSD) [❌], stanza=(sekumpulan/F--) [❌]
# Index 7: manual=(harimau/NSD), gpt=(harimau/NSD) [✅], stanza=(harimau/F--) [❌]
# Index 8: manual=(Sumatera/NSD), gpt=(Sumatera/F--) [❌], stanza=(Sumatera/NSD) [✅]
# Index 9: manual=((/Z--), gpt=((/Z--) [✅], stanza=((/Z--) [✅]
# Index 10: manual=(Panthera/F--), gpt=(Panthera/F--) [✅], stanza=(Panthera/F--) [✅]
# Index 11: manual=(tigris/F--), gpt=(tigris/F--) [✅], stanza=(tigris/F--) [✅]
# Index 12: manual=(sumatrae/F--), gpt=(sumatrae/F--) [✅], stanza=(sumatrae/F--) [✅]
# Index 13: manual=()/Z--), gpt=()/Z--) [✅], stanza=()/Z--) [✅]
# Index 14: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 15: manual=(Pengamatan/NSD), gpt=(Pengamatan/NSD) [✅], stanza=(Pengamatan/NSD) [✅]
# Index 16: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 17: manual=(dilakukan/VBT), gpt=(dilakukan/VSP) [❌], stanza=(dilakukan/VSP) [❌]
# Index 18: manual=(oleh/ADV), gpt=(oleh/ADV) [✅], stanza=(oleh/ADV) [✅]
# Index 19: manual=(sekelompok/NUM), gpt=(sekelompok/NSD) [❌], stanza=(sekelompok/ADV) [❌]
# Index 20: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 21: manual=(dilakukan/VSP), gpt=(dilakukan/VSP) [✅], stanza=(dilakukan/VSP) [✅]
# Index 22: manual=(pada/ADV), gpt=(pada/ADV) [✅], stanza=(pada/ADV) [✅]
# Index 23: manual=(tingkat/NSD), gpt=(tingkat/NSD) [✅], stanza=(tingkat/NSD) [✅]
#
# === Kalimat ke-36 ===
# Index 0: manual=(Peneliti/NSD), gpt=(Peneliti/NSD) [✅], stanza=(Peneliti/NSD) [✅]
# Index 1: manual=(mempelajari/VBT), gpt=(mempelajari/VSA) [❌], stanza=(mempelajari/VSA) [❌]
# Index 2: manual=(perilaku/NSD), gpt=(perilaku/NSD) [✅], stanza=(perilaku/NSD) [✅]
# Index 3: manual=(harimau/NSD), gpt=(harimau/NSD) [✅], stanza=(harimau/F--) [❌]
# Index 4: manual=(Sumatera/NSD), gpt=(Sumatera/F--) [❌], stanza=(Sumatera/NSD) [✅]
# Index 5: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 6: manual=(Studi/NSD), gpt=(Studi/NSD) [✅], stanza=(Studi/NSD) [✅]
# Index 7: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 8: manual=(dilakukan/VSP), gpt=(dilakukan/VSP) [✅], stanza=(dilakukan/VSP) [✅]
# Index 9: manual=(pada/ADV), gpt=(pada/ADV) [✅], stanza=(pada/ADV) [✅]
# Index 10: manual=(tingkat/NSD), gpt=(tingkat/NSD) [✅], stanza=(tingkat/NSD) [✅]
#
# === Kalimat ke-37 ===
# Index 0: manual=(Tumbuhan/NSD), gpt=(Tumbuhan/NSD) [✅], stanza=(Tumbuhan/NSD) [✅]
# Index 1: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 2: manual=(termasuk/VBI), gpt=(termasuk/VSA) [❌], stanza=(termasuk/ADV) [❌]
# Index 3: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 4: manual=(tingkatan/NSD), gpt=(tingkatan/NSD) [✅], stanza=(tingkatan/NSD) [✅]
# Index 5: manual=(satu/NUM), gpt=(satu/O--) [❌], stanza=(satu/CC-) [❌]
# Index 6: manual=(gen/NSD), gpt=(gen/NSD) [✅], stanza=(gen/NSD) [✅]
# Index 7: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-38 ===
# Index 0: manual=(Kelompok/NUM), gpt=(Kelompok/NSD) [❌], stanza=(Kelompok/NSD) [❌]
# Index 1: manual=(tumbuhan/NSD), gpt=(tumbuhan/NSD) [✅], stanza=(tumbuhan/NSD) [✅]
# Index 2: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 3: manual=(merupakan/VBL), gpt=(merupakan/VSA) [❌], stanza=(merupakan/O--) [❌]
# Index 4: manual=(tingkatan/NSD), gpt=(tingkatan/NSD) [✅], stanza=(tingkatan/NSD) [✅]
# Index 5: manual=(satu/NUM), gpt=(satu/O--) [❌], stanza=(satu/CC-) [❌]
# Index 6: manual=(gen/NSD), gpt=(gen/NSD) [✅], stanza=(gen/NSD) [✅]
# Index 7: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-39 ===
# Index 0: manual=(Kelompok/NUM), gpt=(Kelompok/NSD) [❌], stanza=(Kelompok/NSD) [❌]
# Index 1: manual=(tumbuhan/NSD), gpt=(tumbuhan/NSD) [✅], stanza=(tumbuhan/NSD) [✅]
# Index 2: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 3: manual=(tingkatan/NSD), gpt=(tingkatan/NSD) [✅], stanza=(tingkatan/NSD) [✅]
# Index 4: manual=(satu/NUM), gpt=(satu/O--) [❌], stanza=(satu/CC-) [❌]
# Index 5: manual=(gen/NSD), gpt=(gen/NSD) [✅], stanza=(gen/NSD) [✅]
# Index 6: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-40 ===
# Index 0: manual=(Beberapa/NUM), gpt=(Beberapa/O--) [❌], stanza=(Beberapa/B--) [❌]
# Index 1: manual=(bakteri/NSD), gpt=(bakteri/NSD) [✅], stanza=(bakteri/NSD) [✅]
# Index 2: manual=(hidup/VBI), gpt=(hidup/VSA) [❌], stanza=(hidup/NSD) [❌]
# Index 3: manual=(bebas/ADJ), gpt=(bebas/ADV) [❌], stanza=(bebas/ADV) [❌]
# Index 4: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 5: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 6: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 7: manual=(bisa/VSA), gpt=(bisa/VSA) [✅], stanza=(bisa/M--) [❌]
# Index 8: manual=(membuat/VBT), gpt=(membuat/VSA) [❌], stanza=(membuat/VSA) [❌]
# Index 9: manual=(makanan/NSD), gpt=(makanannya/NSD) [❌], stanza=(makanan/NSD) [✅]
# Index 10: manual=(nya/PRF), gpt=(PAD/PAD) [❌], stanza=(nya/PRF) [✅]
# Index 11: manual=(sendiri/ADJ), gpt=(sendiri/ADV) [❌], stanza=(sendiri/ADV) [❌]
# Index 12: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 13: manual=(Sifat/NSD), gpt=(Sifat/NSD) [✅], stanza=(Sifat/NSD) [✅]
# Index 14: manual=(hidup/VBI), gpt=(hidup/VSA) [❌], stanza=(hidup/NSD) [❌]
# Index 15: manual=(seperti/ADV), gpt=(seperti/ADV) [✅], stanza=(seperti/ADV) [✅]
# Index 16: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 17: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
#
# === Kalimat ke-41 ===
# Index 0: manual=(Bakteri/NSD), gpt=(Bakteri/NSD) [✅], stanza=(Bakteri/NSD) [✅]
# Index 1: manual=(tertentu/B--), gpt=(tertentu/ADV) [❌], stanza=(tertentu/B--) [✅]
# Index 2: manual=(dapat/VSA), gpt=(dapat/VSA) [✅], stanza=(dapat/VSA) [✅]
# Index 3: manual=(hidup/VBI), gpt=(hidup/VSA) [❌], stanza=(hidup/NSD) [❌]
# Index 4: manual=(bebas/ADJ), gpt=(bebas/ADV) [❌], stanza=(bebas/ADV) [❌]
# Index 5: manual=(di/ADV), gpt=(di/ADV) [✅], stanza=(di/ADV) [✅]
# Index 6: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 7: manual=(dan/ADV), gpt=(dan/CC-) [❌], stanza=(dan/H--) [❌]
# Index 8: manual=(membuat/VBT), gpt=(membuat/VSA) [❌], stanza=(membuat/VSA) [❌]
# Index 9: manual=(makanan/NSD), gpt=(makanannya/NSD) [❌], stanza=(makanan/NSD) [✅]
# Index 10: manual=(nya/PRF), gpt=(PAD/PAD) [❌], stanza=(nya/PRF) [✅]
# Index 11: manual=(sendiri/ADJ), gpt=(sendiri/ADV) [❌], stanza=(sendiri/ADV) [❌]
# Index 12: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 13: manual=(Sifat/NSD), gpt=(Sifat/NSD) [✅], stanza=(Sifat/NSD) [✅]
# Index 14: manual=(hidup/VBI), gpt=(hidup/VSA) [❌], stanza=(hidup/NSD) [❌]
# Index 15: manual=(seperti/ADV), gpt=(seperti/ADV) [✅], stanza=(seperti/ADV) [✅]
# Index 16: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 17: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
#
# === Kalimat ke-42 ===
# Index 0: manual=(Sebagian/NUM), gpt=(Sebagian/O--) [❌], stanza=(Sebagian/ADV) [❌]
# Index 1: manual=(bakteri/NSD), gpt=(bakteri/NSD) [✅], stanza=(bakteri/NSD) [✅]
# Index 2: manual=(hidup/NSD), gpt=(hidup/VSA) [❌], stanza=(hidup/NSD) [✅]
# Index 3: manual=(bebas/ADJ), gpt=(bebas/ADV) [❌], stanza=(bebas/ADV) [❌]
# Index 4: manual=(di/PRD), gpt=(di/ADV) [❌], stanza=(di/ADV) [❌]
# Index 5: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 6: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 7: manual=(dapat/VSA), gpt=(dapat/VSA) [✅], stanza=(dapat/VSA) [✅]
# Index 8: manual=(menyintesis/VBT), gpt=(menyintesis/VSA) [❌], stanza=(menyintesis/VSA) [❌]
# Index 9: manual=(makanan/NSD), gpt=(makanannya/NSD) [❌], stanza=(makanan/NSD) [✅]
# Index 10: manual=(nya/PRF), gpt=(PAD/PAD) [❌], stanza=(nya/PRF) [✅]
# Index 11: manual=(sendiri/ADV), gpt=(sendiri/ADV) [✅], stanza=(sendiri/ADV) [✅]
# Index 12: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 13: manual=(Sifat/NSD), gpt=(Sifat/NSD) [✅], stanza=(Sifat/NSD) [✅]
# Index 14: manual=(hidup/VBI), gpt=(hidup/VSA) [❌], stanza=(hidup/NSD) [❌]
# Index 15: manual=(seperti/ADV), gpt=(seperti/ADV) [✅], stanza=(seperti/ADV) [✅]
# Index 16: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 17: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
#
# === Kalimat ke-43 ===
# Index 0: manual=(Bakteri/NSD), gpt=(Bakteri/NSD) [✅], stanza=(Bakteri/NSD) [✅]
# Index 1: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 2: manual=(membantu/VBT), gpt=(membantu/VSA) [❌], stanza=(membantu/VSA) [❌]
# Index 3: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 4: manual=(pertanian/NSD), gpt=(pertanian/NSD) [✅], stanza=(pertanian/NSD) [✅]
# Index 5: manual=(dengan/ADV), gpt=(dengan/ADV) [✅], stanza=(dengan/ADV) [✅]
# Index 6: manual=(hidup/VBI), gpt=(hidup/VSA) [❌], stanza=(hidup/NSD) [❌]
# Index 7: manual=(bersama/ADV), gpt=(bersama/ADV) [✅], stanza=(bersama/VSA) [❌]
# Index 8: manual=(akar/NSD), gpt=(akar/NSD) [✅], stanza=(akar/NSD) [✅]
# Index 9: manual=(tumbuhan/NSD), gpt=(tumbuhan/NSD) [✅], stanza=(tumbuhan/NSD) [✅]
# Index 10: manual=(kacang/NSD), gpt=(kacang-kacangan/NSD) [❌], stanza=(kacang-kacangan/NSD) [❌]
# Index 11: manual=(-/Z--), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 12: manual=(kacangan/NSD), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 13: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 14: manual=(Bakteri/NSD), gpt=(Bakteri/NSD) [✅], stanza=(Bakteri/NSD) [✅]
# Index 15: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 16: manual=(adalah/VBL), gpt=(adalah/VSA) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-44 ===
# Index 0: manual=(Bakteri/NSD), gpt=(Bakteri/NSD) [✅], stanza=(Bakteri/NSD) [✅]
# Index 1: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 2: manual=(berkolaborasi/VBI), gpt=(berkolaborasi/VSA) [❌], stanza=(berkolaborasi/VSA) [❌]
# Index 3: manual=(dengan/ADV), gpt=(dengan/ADV) [✅], stanza=(dengan/ADV) [✅]
# Index 4: manual=(akar/NSD), gpt=(akar/NSD) [✅], stanza=(akar/NSD) [✅]
# Index 5: manual=(tumbuhan/NSD), gpt=(tumbuhan/NSD) [✅], stanza=(tumbuhan/NSD) [✅]
# Index 6: manual=(kacang/NSD), gpt=(kacang-kacangan/NSD) [❌], stanza=(kacang-kacangan/NSD) [❌]
# Index 7: manual=(-/Z--), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 8: manual=(kacangan/NSD), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 9: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 10: manual=(meningkatkan/VBT), gpt=(meningkatkan/VSA) [❌], stanza=(meningkatkan/VSA) [❌]
# Index 11: manual=(hasil/NSD), gpt=(hasil/NSD) [✅], stanza=(hasil/NSD) [✅]
# Index 12: manual=(pertanian/NSD), gpt=(pertanian/NSD) [✅], stanza=(pertanian/NSD) [✅]
# Index 13: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 14: manual=(Bakteri/NSD), gpt=(Bakteri/NSD) [✅], stanza=(Bakteri/NSD) [✅]
# Index 15: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 16: manual=(disebut/VSP), gpt=(disebut/VSP) [✅], stanza=(disebut/VSP) [✅]
#
# ...
# Index 10: manual=(dikendalikan/VSP), gpt=(dikendalikan/VSP) [✅], stanza=(dikendalikan/VSP) [✅]
# Index 11: manual=(secara/ADV), gpt=(secara/ADV) [✅], stanza=(secara/ADV) [✅]
# Index 12: manual=(serius/ADJ), gpt=(serius/ADV) [❌], stanza=(serius/ADV) [❌]
# Index 13: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 14: manual=(Cara/NSD), gpt=(Cara/NSD) [✅], stanza=(Cara/NSD) [✅]
# Index 15: manual=(pengendalian/NSD), gpt=(pengendalian/NSD) [✅], stanza=(pengendalian/NSD) [✅]
# Index 16: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 17: manual=(tidak/ADV), gpt=(tidak/B--) [❌], stanza=(tidak/PRF) [❌]
# Index 18: manual=(menimbulkan/VBT), gpt=(menimbulkan/VSA) [❌], stanza=(menimbulkan/VSA) [❌]
# Index 19: manual=(dampak/NSD), gpt=(dampak/NSD) [✅], stanza=(dampak/NSD) [✅]
# Index 20: manual=(negatif/ADJ), gpt=(negatif/ADV) [❌], stanza=(negatif/F--) [❌]
# Index 21: manual=(bagi/ADV), gpt=(bagi/ADV) [✅], stanza=(bagi/ADV) [✅]
# Index 22: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 23: manual=(adalah/VBL), gpt=(adalah/VSB) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-144 ===
# Index 0: manual=(Populasi/NSD), gpt=(Populasi/NSD) [✅], stanza=(Populasi/NSD) [✅]
# Index 1: manual=(serangga/NSD), gpt=(serangga/NSD) [✅], stanza=(serangga/NSD) [✅]
# Index 2: manual=(perusak/NSD), gpt=(perusak/NSD) [✅], stanza=(perusak/NSD) [✅]
# Index 3: manual=(tanaman/NSD), gpt=(tanaman/NSD) [✅], stanza=(tanaman/NSD) [✅]
# Index 4: manual=(pertanian/NSD), gpt=(pertanian/NSD) [✅], stanza=(pertanian/NSD) [✅]
# Index 5: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 6: manual=(meningkat/VBT), gpt=(meningkat/VSA) [❌], stanza=(meningkat/VSA) [❌]
# Index 7: manual=(perlu/ADV), gpt=(perlu/VSA) [❌], stanza=(perlu/VSA) [❌]
# Index 8: manual=(dikendalikan/VSP), gpt=(dikendalikan/VSP) [✅], stanza=(dikendalikan/VSP) [✅]
# Index 9: manual=(dengan/ADV), gpt=(dengan/ADV) [✅], stanza=(dengan/ADV) [✅]
# Index 10: manual=(serius/ADJ), gpt=(serius/ADV) [❌], stanza=(serius/ADV) [❌]
# Index 11: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 12: manual=(Cara/NSD), gpt=(Cara/NSD) [✅], stanza=(Cara/NSD) [✅]
# Index 13: manual=(pengendalian/NSD), gpt=(pengendalian/NSD) [✅], stanza=(pengendalian/NSD) [✅]
# Index 14: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 15: manual=(ramah/ADJ), gpt=(ramah/ADV) [❌], stanza=(ramah/ADV) [❌]
# Index 16: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 17: manual=(adalah/VBL), gpt=(adalah/VSB) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-145 ===
# Index 0: manual=(Pencemaran/NSD), gpt=(Pencemaran/NSD) [✅], stanza=(Pencemaran/NSD) [✅]
# Index 1: manual=(sampah/NSD), gpt=(sampah/NSD) [✅], stanza=(sampah/NSD) [✅]
# Index 2: manual=(plastik/NSD), gpt=(plastik/NSD) [✅], stanza=(plastik/NSD) [✅]
# Index 3: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 4: manual=(tanah/NSD), gpt=(tanah/NSD) [✅], stanza=(tanah/NSD) [✅]
# Index 5: manual=(selain/ADV), gpt=(selain/ADV) [✅], stanza=(selain/ADV) [✅]
# Index 6: manual=(mengurangi/VBT), gpt=(mengurangi/VSA) [❌], stanza=(mengurangi/VSA) [❌]
# Index 7: manual=(kemampuan/NSD), gpt=(kemampuan/NSD) [✅], stanza=(kemampuan/NSD) [✅]
# Index 8: manual=(daya/NSD), gpt=(daya/NSD) [✅], stanza=(daya/NSD) [✅]
# Index 9: manual=(dukung/VBI), gpt=(dukung/NSD) [❌], stanza=(dukung/VSA) [❌]
# Index 10: manual=(tanah/NSD), gpt=(tanah/NSD) [✅], stanza=(tanah/NSD) [✅]
# Index 11: manual=(juga/ADV), gpt=(juga/B--) [❌], stanza=(juga/D--) [❌]
# Index 12: manual=(merupakan/VBL), gpt=(merupakan/VSB) [❌], stanza=(merupakan/O--) [❌]
# Index 13: manual=(polutan/NSD), gpt=(polutan/NSD) [✅], stanza=(polutan/NSD) [✅]
# Index 14: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 15: manual=(tidak/ADV), gpt=(tidak/B--) [❌], stanza=(tidak/PRF) [❌]
# Index 16: manual=(dapat/VSA), gpt=(dapat/VSA) [✅], stanza=(dapat/VSA) [✅]
# Index 17: manual=(diuraikan/VSP), gpt=(diuraikan/VSP) [✅], stanza=(diuraikan/VSP) [✅]
# Index 18: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 19: manual=(Untuk/ADV), gpt=(Untuk/ADV) [✅], stanza=(Untuk/ADV) [✅]
# Index 20: manual=(menanggulangi/VBT), gpt=(menanggulanginya/VSA) [❌], stanza=(menanggulangi/VSA) [❌]
# Index 21: manual=(nya/PRF), gpt=(PAD/PAD) [❌], stanza=(nya/PRF) [✅]
# Index 22: manual=(dilakukan/VSP), gpt=(dilakukan/VSP) [✅], stanza=(dilakukan/VSP) [✅]
#
# === Kalimat ke-146 ===
# Index 0: manual=(Selain/ADV), gpt=(Selain/ADV) [✅], stanza=(Selain/ADV) [✅]
# Index 1: manual=(mengurangi/VBT), gpt=(mengurangi/VSA) [❌], stanza=(mengurangi/VSA) [❌]
# Index 2: manual=(kemampuan/NSD), gpt=(kemampuan/NSD) [✅], stanza=(kemampuan/NSD) [✅]
# Index 3: manual=(daya/NSD), gpt=(daya/NSD) [✅], stanza=(daya/NSD) [✅]
# Index 4: manual=(dukung/VBI), gpt=(dukung/NSD) [❌], stanza=(dukung/VSA) [❌]
# Index 5: manual=(tanah/NSD), gpt=(tanah/NSD) [✅], stanza=(tanah/NSD) [✅]
# Index 6: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 7: manual=(pencemaran/NSD), gpt=(pencemaran/NSD) [✅], stanza=(pencemaran/NSD) [✅]
# Index 8: manual=(sampah/NSD), gpt=(sampah/NSD) [✅], stanza=(sampah/NSD) [✅]
# Index 9: manual=(plastik/NSD), gpt=(plastik/NSD) [✅], stanza=(plastik/ADV) [❌]
# Index 10: manual=(juga/ADV), gpt=(juga/B--) [❌], stanza=(juga/D--) [❌]
# Index 11: manual=(tidak/ADV), gpt=(tidak/B--) [❌], stanza=(tidak/PRF) [❌]
# Index 12: manual=(dapat/VSA), gpt=(dapat/VSA) [✅], stanza=(dapat/VSA) [✅]
# Index 13: manual=(diuraikan/VSP), gpt=(diuraikan/VSP) [✅], stanza=(diuraikan/VSP) [✅]
# Index 14: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 15: manual=(Upaya/NSD), gpt=(Upaya/NSD) [✅], stanza=(Upaya/NSD) [✅]
# Index 16: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 17: manual=(menanggulangi/VBT), gpt=(menanggulangi/VSA) [❌], stanza=(menanggulangi/VSA) [❌]
# Index 18: manual=(hal/NSD), gpt=(hal/NSD) [✅], stanza=(hal/NSD) [✅]
# Index 19: manual=(ini/PRD), gpt=(ini/PRD) [✅], stanza=(ini/B--) [❌]
# Index 20: manual=(adalah/VBL), gpt=(adalah/VSB) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-147 ===
# Index 0: manual=(Pencemaran/NSD), gpt=(Pencemaran/NSD) [✅], stanza=(Pencemaran/NSD) [✅]
# Index 1: manual=(plastik/NSD), gpt=(plastik/NSD) [✅], stanza=(plastik/NSD) [✅]
# Index 2: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 3: manual=(tanah/NSD), gpt=(tanah/NSD) [✅], stanza=(tanah/NSD) [✅]
# Index 4: manual=(mengurangi/NSD), gpt=(mengurangi/VSA) [❌], stanza=(mengurangi/VSA) [❌]
# Index 5: manual=(daya/NSD), gpt=(daya/NSD) [✅], stanza=(daya/NSD) [✅]
# Index 6: manual=(dukung/VBI), gpt=(dukung/NSD) [❌], stanza=(dukung/VSA) [❌]
# Index 7: manual=(tanah/NSD), gpt=(tanah/NSD) [✅], stanza=(tanah/NSD) [✅]
# Index 8: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 9: manual=(tidak/ADV), gpt=(tidak/B--) [❌], stanza=(tidak/PRF) [❌]
# Index 10: manual=(bisa/VSA), gpt=(bisa/VSA) [✅], stanza=(bisa/M--) [❌]
# Index 11: manual=(diuraikan/VSP), gpt=(diuraikan/VSP) [✅], stanza=(diuraikan/VSP) [✅]
# Index 12: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 13: manual=(Upaya/NSD), gpt=(Upaya/NSD) [✅], stanza=(Upaya/NSD) [✅]
# Index 14: manual=(penanggulangan/NSD), gpt=(penanggulangannya/NSD) [❌], stanza=(penanggulangan/NSD) [✅]
# Index 15: manual=(nya/PRF), gpt=(PAD/PAD) [❌], stanza=(nya/PRF) [✅]
# Index 16: manual=(adalah/VBL), gpt=(adalah/VSB) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-148 ===
# Index 0: manual=(Penggunaan/NSD), gpt=(Penggunaan/NSD) [✅], stanza=(Penggunaan/NSD) [✅]
# Index 1: manual=(kendaraan/NSD), gpt=(kendaraan/NSD) [✅], stanza=(kendaraan/NSD) [✅]
# Index 2: manual=(bermotor/ADV), gpt=(bermotor/ADV) [✅], stanza=(bermotor/VSA) [❌]
# Index 3: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 4: manual=(alat/NSD), gpt=(alat-alat/NSD) [❌], stanza=(alat-alat/NSD) [❌]
# Index 5: manual=(-/Z--), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 6: manual=(alat/NSD), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 7: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 8: manual=(/VBT), gpt=(mengandung/VSA) [❌], stanza=(mengandung/VSA) [❌]
# Index 9: manual=(CFC/F--), gpt=(CFC/NSD) [❌], stanza=(CFC/F--) [✅]
# Index 10: manual=(bisa/VSA), gpt=(bisa/VSA) [✅], stanza=(bisa/M--) [❌]
# Index 11: manual=(menyebabkan/VBT), gpt=(menyebabkan/VSA) [❌], stanza=(menyebabkan/VSA) [❌]
#
# === Kalimat ke-149 ===
# Index 0: manual=(Kendaraan/NSD), gpt=(Kendaraan/NSD) [✅], stanza=(Kendaraan/NSD) [✅]
# Index 1: manual=(bermotor/ADV), gpt=(bermotor/ADV) [✅], stanza=(bermotor/VSA) [❌]
# Index 2: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 3: manual=(alat/NSD), gpt=(alat-alat/NSD) [❌], stanza=(alat-alat/NSD) [❌]
# Index 4: manual=(-/Z--), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 5: manual=(alat/NSD), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 6: manual=(dengan/ADV), gpt=(dengan/ADV) [✅], stanza=(dengan/ADV) [✅]
# Index 7: manual=(CFC/F--), gpt=(CFC/NSD) [❌], stanza=(CFC/F--) [✅]
# Index 8: manual=(dapat/VSA), gpt=(dapat/VSA) [✅], stanza=(dapat/VSA) [✅]
# Index 9: manual=(mengakibatkan/VBT), gpt=(mengakibatkan/VSA) [❌], stanza=(mengakibatkan/VSA) [❌]
#
# === Kalimat ke-150 ===
# Index 0: manual=(Akibat/NSD), gpt=(Akibat/NSD) [✅], stanza=(Akibat/NSD) [✅]
# Index 1: manual=(dari/ADV), gpt=(dari/ADV) [✅], stanza=(dari/ADV) [✅]
# Index 2: manual=(penggunaan/NSD), gpt=(penggunaan/NSD) [✅], stanza=(penggunaan/NSD) [✅]
# Index 3: manual=(kendaraan/NSD), gpt=(kendaraan/NSD) [✅], stanza=(kendaraan/NSD) [✅]
# Index 4: manual=(bermotor/ADV), gpt=(bermotor/ADV) [✅], stanza=(bermotor/VSA) [❌]
# Index 5: manual=(dan/CC-), gpt=(dan/CC-) [✅], stanza=(dan/H--) [❌]
# Index 6: manual=(alat/NSD), gpt=(alat-alat/NSD) [❌], stanza=(alat-alat/NSD) [❌]
# Index 7: manual=(-/Z--), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 8: manual=(alat/NSD), gpt=(PAD/PAD) [❌], stanza=(PAD/PAD) [❌]
# Index 9: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 10: manual=(mengandung/VBT), gpt=(mengandung/VSA) [❌], stanza=(mengandung/VSA) [❌]
# Index 11: manual=(CFC/F--), gpt=(CFC/NSD) [❌], stanza=(CFC/F--) [✅]
# Index 12: manual=(adalah/VBL), gpt=(adalah/VSB) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-151 ===
# Index 0: manual=(Tindakan/NSD), gpt=(Tindakan/NSD) [✅], stanza=(Tindakan/NSD) [✅]
# Index 1: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 2: manual=(kita/PRP), gpt=(kita/PRD) [❌], stanza=(kita/PRP) [✅]
# Index 3: manual=(lakukan/VSA), gpt=(lakukan/VSA) [✅], stanza=(lakukan/VSA) [✅]
# Index 4: manual=(untuk/ADV), gpt=(untuk/ADV) [✅], stanza=(untuk/ADV) [✅]
# Index 5: manual=(menerapkan/VBT), gpt=(menerapkan/VSA) [❌], stanza=(menerapkan/VSA) [❌]
# Index 6: manual=(prinsip/NSD), gpt=(prinsip/NSD) [✅], stanza=(prinsip/NSD) [✅]
# Index 7: manual=(etika/NSD), gpt=(etika/NSD) [✅], stanza=(etika/NSD) [✅]
# Index 8: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 9: manual=(tersebut/PRD), gpt=(tersebut/PRD) [✅], stanza=(tersebut/B--) [❌]
# Index 10: manual=(adalah/VBL), gpt=(adalah/VSB) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-152 ===
# Index 0: manual=(Dalam/ADV), gpt=(Dalam/ADV) [✅], stanza=(Dalam/NSD) [❌]
# Index 1: manual=(rangka/NSD), gpt=(rangka/NSD) [✅], stanza=(rangka/NSD) [✅]
# Index 2: manual=(menerapkan/VBT), gpt=(menerapkan/VSA) [❌], stanza=(menerapkan/VSA) [❌]
# Index 3: manual=(prinsip/NSD), gpt=(prinsip/NSD) [✅], stanza=(prinsip/NSD) [✅]
# Index 4: manual=(etika/NSD), gpt=(etika/NSD) [✅], stanza=(etika/NSD) [✅]
# Index 5: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 6: manual=(tersebut/PRD), gpt=(tersebut/T--) [❌], stanza=(tersebut/B--) [❌]
# Index 7: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 8: manual=(tindakan/NSD), gpt=(tindakan/NSD) [✅], stanza=(tindakan/NSD) [✅]
# Index 9: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]
# Index 10: manual=(kita/PRP), gpt=(kita/PRF) [❌], stanza=(kita/PRP) [✅]
# Index 11: manual=(ambil/VSA), gpt=(ambil/VSA) [✅], stanza=(ambil/VSA) [✅]
# Index 12: manual=(adalah/VBL), gpt=(adalah/VSP) [❌], stanza=(adalah/O--) [❌]
#
# === Kalimat ke-153 ===
# Index 0: manual=(Untuk/ADV), gpt=(Untuk/ADV) [✅], stanza=(Untuk/ADV) [✅]
# Index 1: manual=(menjalankan/VBT), gpt=(menjalankan/VSA) [❌], stanza=(menjalankan/VSA) [❌]
# Index 2: manual=(prinsip/NSD), gpt=(prinsip/NSD) [✅], stanza=(prinsip/NSD) [✅]
# Index 3: manual=(etika/NSD), gpt=(etika/NSD) [✅], stanza=(etika/NSD) [✅]
# Index 4: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 5: manual=(itu/PRD), gpt=(itu/T--) [❌], stanza=(itu/B--) [❌]
# Index 6: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 7: manual=(kita/PRP), gpt=(kita/PRF) [❌], stanza=(kita/PRP) [✅]
# Index 8: manual=(perlu/VSA), gpt=(perlu/VSA) [✅], stanza=(perlu/VSA) [✅]
# Index 9: manual=(melakukan/VBT), gpt=(melakukan/VSA) [❌], stanza=(melakukan/VSA) [❌]
# Index 10: manual=(tindakan/NSD), gpt=(tindakan/NSD) [✅], stanza=(tindakan/NSD) [✅]
#
# === Kalimat ke-154 ===
# Index 0: manual=(Salah/NSD), gpt=(Salah/ADV) [❌], stanza=(Salah/ADV) [❌]
# Index 1: manual=(satu/NUM), gpt=(satu/O--) [❌], stanza=(satu/CC-) [❌]
# Index 2: manual=(pengaruh/NSD), gpt=(pengaruh/NSD) [✅], stanza=(pengaruh/NSD) [✅]
# Index 3: manual=(hutan/NSD), gpt=(hutan/NSD) [✅], stanza=(hutan/NSD) [✅]
# Index 4: manual=(terhadap/ADV), gpt=(terhadap/ADV) [✅], stanza=(terhadap/ADV) [✅]
# Index 5: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 6: manual=(adalah/VBL), gpt=(adalah/VSP) [❌], stanza=(adalah/O--) [❌]
# Index 7: manual=(hubungan/NSD), gpt=(hubungannya/NSD) [❌], stanza=(hubungan/NSD) [✅]
# Index 8: manual=(nya/PRF), gpt=(PAD/PAD) [❌], stanza=(nya/PRF) [✅]
# Index 9: manual=(dengan/ADV), gpt=(dengan/ADV) [✅], stanza=(dengan/ADV) [✅]
# Index 10: manual=(iklim/NSD), gpt=(iklim/NSD) [✅], stanza=(iklim/NSD) [✅]
# Index 11: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 12: manual=(Ini/PRD), gpt=(Ini/PRF) [❌], stanza=(Ini/B--) [❌]
# Index 13: manual=(terjadi/VBI), gpt=(terjadi/VSA) [❌], stanza=(terjadi/VSP) [❌]
# Index 14: manual=(karena/ADV), gpt=(karena/S--) [❌], stanza=(karena/S--) [❌]
# Index 15: manual=(hutan/NSD), gpt=(hutan/NSD) [✅], stanza=(hutan/NSD) [✅]
#
# === Kalimat ke-155 ===
# Index 0: manual=(Hutan/NSD), gpt=(Hutan/NSD) [✅], stanza=(Hutan/NSD) [✅]
# Index 1: manual=(mempengaruhi/VBT), gpt=(mempengaruhi/VSA) [❌], stanza=(mempengaruhi/VSA) [❌]
# Index 2: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 3: manual=(,/Z--), gpt=(,/Z--) [✅], stanza=(,/Z--) [✅]
# Index 4: manual=(terutama/ADJ), gpt=(terutama/B--) [❌], stanza=(terutama/ASS) [❌]
# Index 5: manual=(dalam/ADV), gpt=(dalam/ADV) [✅], stanza=(dalam/ADV) [✅]
# Index 6: manual=(hal/NSD), gpt=(hal/NSD) [✅], stanza=(hal/NSD) [✅]
# Index 7: manual=(iklim/NSD), gpt=(iklim/NSD) [✅], stanza=(iklim/NSD) [✅]
# Index 8: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 9: manual=(Ini/PRD), gpt=(Ini/PRF) [❌], stanza=(Ini/B--) [❌]
# Index 10: manual=(karena/ADV), gpt=(karena/S--) [❌], stanza=(karena/S--) [❌]
# Index 11: manual=(hutan/NSD), gpt=(hutan/NSD) [✅], stanza=(hutan/NSD) [✅]
#
# === Kalimat ke-156 ===
# Index 0: manual=(Pengaruh/NSD), gpt=(Pengaruh/NSD) [✅], stanza=(Pengaruh/NSD) [✅]
# Index 1: manual=(hutan/NSD), gpt=(hutan/NSD) [✅], stanza=(hutan/NSD) [✅]
# Index 2: manual=(terhadap/ADV), gpt=(terhadap/ADV) [✅], stanza=(terhadap/ADV) [✅]
# Index 3: manual=(lingkungan/NSD), gpt=(lingkungan/NSD) [✅], stanza=(lingkungan/NSD) [✅]
# Index 4: manual=(mencakup/VBT), gpt=(mencakup/VSA) [❌], stanza=(mencakup/VSA) [❌]
# Index 5: manual=(iklim/NSD), gpt=(iklim/NSD) [✅], stanza=(iklim/NSD) [✅]
# Index 6: manual=(./Z--), gpt=(./Z--) [✅], stanza=(./Z--) [✅]
# Index 7: manual=(Hal/NSD), gpt=(Hal/NSD) [✅], stanza=(Hal/NSD) [✅]
# Index 8: manual=(ini/PRD), gpt=(ini/T--) [❌], stanza=(ini/B--) [❌]
# Index 9: manual=(disebabkan/VSP), gpt=(disebabkan/VSP) [✅], stanza=(disebabkan/VSP) [✅]
# Index 10: manual=(oleh/ADV), gpt=(oleh/ADV) [✅], stanza=(oleh/ADV) [✅]
# Index 11: manual=(hutan/NSD), gpt=(hutan/NSD) [✅], stanza=(hutan/NSD) [✅]
# Index 12: manual=(yang/S--), gpt=(yang/S--) [✅], stanza=(yang/S--) [✅]

# %%
total_manual_tokens = 0
total_gpt_correct = 0
total_stanza_correct = 0

for i, row in df.iterrows():
    gpt = parse_tagged_sentence(row['gpt'])
    stanza = parse_tagged_sentence(row['stanza'])
    manual = parse_tagged_sentence(row['manual'])

    evaluated = evaluate_tags(gpt, stanza, manual)

    for r in evaluated:
        if r['manual_token'] is not None:
            total_manual_tokens += 1
            if r['gpt_correct']:
                total_gpt_correct += 1
            if r['stanza_correct']:
                total_stanza_correct += 1

gpt_accuracy = total_gpt_correct / total_manual_tokens if total_manual_tokens else 0
stanza_accuracy = total_stanza_correct / total_manual_tokens if total_manual_tokens else 0

print(f"Akurasi GPT: {gpt_accuracy:.2%}")
print(f"Akurasi Stanza: {stanza_accuracy:.2%}")
# Out:
# Akurasi GPT: 62.68%
# Akurasi Stanza: 61.60%
